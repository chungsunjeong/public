# %%
from IPython.display import display
import numpy as np
import pandas as pd

# %% [markdown]
# ## Dataset grasp

# %%
with open('./dir_dataset.txt','r') as f:
    dataset_dir=f.readline()
dataset_dir+='2008, Yamanishi\enzyme'
print(dataset_dir)
# Out:
# C:\Users\csjeong\Desktop\research\dataset\conv_DTI\2008, Yamanishi\enzyme

# %%
dir_list_DTI=dataset_dir+'\\1_bind_orfhsa_drug_e.txt'
dir_adjmat_DTI=dataset_dir+'\\2_e_admat_dgc.txt'
dir_simmat_comp=dataset_dir+'\\3_e_simmat_dc.txt'
dir_simmat_prot=dataset_dir+'\\4_e_simmat_dg.txt'
print(dir_list_DTI)
# Out:
# C:\Users\csjeong\Desktop\research\dataset\conv_DTI\2008, Yamanishi\enzyme\1_bind_orfhsa_drug_e.txt

# %%
matrix=pd.read_table(dir_adjmat_DTI,delim_whitespace=True)
print(matrix)
# Out:
#           D00002  D00005  D00007  D00014  D00018  D00021  D00027  D00029  \
# hsa10          1       0       0       0       0       0       0       0
# hsa100         0       0       0       0       0       0       0       0
# hsa10056       0       0       0       0       0       1       0       0
# hsa1017        0       0       0       0       0       0       0       0
# hsa1018        0       0       0       0       0       0       0       0
# hsa10188       0       0       0       0       0       0       0       0
# hsa1019        0       0       0       0       0       0       0       0
# hsa1020        0       0       0       0       0       0       0       0
# hsa1021        0       0       0       0       0       0       0       0
# hsa1022        0       0       0       0       0       0       0       0
# hsa1024        0       0       0       0       0       0       0       0
# hsa1025        0       0       0       0       0       0       0       0
# ...

# %%
# Out:
# C:\Users\csjeong\Desktop\research\dataset\conv_DTI\2008, Yamanishi\enzyme\2_e_admat_dgc.txt
